# %%
# First let's import the packages we will use in this project
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv('movies.csv')

# %%
# Let's look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Looking for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(f"{col} - {pct_missing}%")
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# so there are some missing values. We will drop those rows with missing values

df = df.dropna(how='any',axis=0)

# %%
# Data types of our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
## Changing data types
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
df.sample(20)
# Out:
#                          name rating      genre  year  \
# 929              The Big Easy      R     Comedy  1986
# 3703         The Replacements  PG-13     Comedy  2000
# 2304          A Perfect World  PG-13      Crime  1993
# 6146            Mirror Mirror     PG  Adventure  2012
# 6303                   Stoker      R      Drama  2013
# 3563      Ride with the Devil      R      Drama  1999
# 5585           Whatever Works  PG-13     Comedy  2009
# 6902                  Inferno  PG-13     Action  2016
# 1466                    Glory      R  Biography  1989
# 3480                Big Daddy  PG-13     Comedy  1999
# 2560          Renaissance Man  PG-13     Comedy  1994
# 792      The Care Bears Movie      G  Animation  1985
# 5876                Limitless  PG-13     Sci-Fi  2011
# 4972             Just My Luck  PG-13     Comedy  2006
# 3086  Speed 2: Cruise Control  PG-13     Action  1997
# 4661           Fantastic Four  PG-13     Action  2005
# ...

# %%
# As we can see the year in 'year' column and year in 'release' column don't match
# Creating a new column yearCorrect

df['yearCorrect'] = df['released'].astype(str).str.split(', ').str[-1].astype(str).str[:4]

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
# Let's check out some of the highest grossing movies

df.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
# looking for duplicates values
duplicate = df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime, yearCorrect]
# Index: []

# %%
# There are no duplicate rows in this dataset.

# %%
# Scatter plot of budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])

plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget ')
plt.ylabel('Gross Earning ');

# %%
# plot  budget vs gross using seaborn

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {'color':'red'}, line_kws = {'color':'blue'});

# %%
# Let's look at the correlation between different columns

correlation_matrix = df.corr(method = 'pearson')
correlation_matrix
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# We can see there high correlation between gross earning and budget of the movie.

# %%
# Heatmap
sns.heatmap(correlation_matrix, annot = True)
plt.title('Correlation Matrix for Numeric Features');

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000  0.169808  0.028413  0.965461  0.966086 -0.020083
# rating       0.169808  1.000000 -0.116507  0.179456  0.171063  0.036114
# genre        0.028413 -0.116507  1.000000  0.031765  0.031251 -0.027402
# year         0.965461  0.179456  0.031765  1.000000  0.996490 -0.014594
# released     0.966086  0.171063  0.031251  0.996490  1.000000 -0.019486
# score       -0.020083  0.036114 -0.027402 -0.014594 -0.019486  1.000000
# votes        0.297305  0.097619 -0.009983  0.323916  0.313254 -0.041981
# director     0.725411  0.096014  0.036671  0.747785  0.750825 -0.006583
# writer       0.791872  0.128909  0.033975  0.812386  0.809858 -0.021538
# star         0.695124  0.115694  0.045497  0.719373  0.720076  0.015108
# country      0.098110 -0.004547 -0.003314  0.095073  0.096807  0.016567
# budget       0.288955  0.203698  0.020893  0.319135  0.309616 -0.005493
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies");

# %%
correlation_matrix
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000  0.169808  0.028413  0.965461  0.966086 -0.020083
# rating       0.169808  1.000000 -0.116507  0.179456  0.171063  0.036114
# genre        0.028413 -0.116507  1.000000  0.031765  0.031251 -0.027402
# year         0.965461  0.179456  0.031765  1.000000  0.996490 -0.014594
# released     0.966086  0.171063  0.031251  0.996490  1.000000 -0.019486
# score       -0.020083  0.036114 -0.027402 -0.014594 -0.019486  1.000000
# votes        0.297305  0.097619 -0.009983  0.323916  0.313254 -0.041981
# director     0.725411  0.096014  0.036671  0.747785  0.750825 -0.006583
# writer       0.791872  0.128909  0.033975  0.812386  0.809858 -0.021538
# star         0.695124  0.115694  0.045497  0.719373  0.720076  0.015108
# country      0.098110 -0.004547 -0.003314  0.095073  0.096807  0.016567
# budget       0.288955  0.203698  0.020893  0.319135  0.309616 -0.005493
# ...

# %%
corr_pairs = correlation_matrix.unstack()

sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head(20)
# Out:
# rating    genre      -0.116507
# genre     rating     -0.116507
# budget    company    -0.053573
# company   budget     -0.053573
# score     votes      -0.041981
# votes     score      -0.041981
# genre     score      -0.027402
# score     genre      -0.027402
# runtime   director   -0.026918
# director  runtime    -0.026918
# rating    company    -0.026286
# company   rating     -0.026286
# country   votes      -0.021562
# votes     country    -0.021562
# writer    score      -0.021538
# score     writer     -0.021538
#           name       -0.020083
# name      score      -0.020083
# score     released   -0.019486
# released  score      -0.019486
# dtype: float64
